# %% [markdown]
# # Programming for artists

# %% [markdown]
# ## Standard Data Types

# %% [markdown]
# Every name and every expression has a type that determines the operations that may be performed on it.
#
# A declaration is a statement that introduces an identifier into the program.
# A Variable is a piece of data which can be stored. The value of this data can be changed.

# %%
name = "kilokon"

# Variable name is of type String. that is name is a name is a string value.

# %% [markdown]
# - Numeric
# - Boolean
# - Binary Sequence Types — bytes, bytearray, memoryview
# - String
# - Sequence
# - Generator
# - Dictionary

# %% [markdown]
# __Numeric__: There are three distinct numeric types: integers, floating-point numbers, and complex numbers.
#
# __Generator Type__:
# __Sequence Types__: There are three basic sequence types: lists, tuples, and range objects.
#
#
# __Bytes Objects__:
# Bytes objects are immutable sequences of single bytes. Since many major binary protocols are based on the ASCII text encoding, bytes objects offer several methods that are only valid when working with ASCII compatible data and are closely related to string objects in a variety of other ways.
#
# __Bytearray Objects__:
# Bytearray objects are a mutable counterpart to bytes objects.
#
# __Memoryview Objects__:
# A memoryview object provides a interface into a bytes-like object (e.g., bytes, bytearray, etc.) to allow efficient slicing, manipulation, or sharing of data.

# %%
# DataType : NoneType
foo = None

# DataType : bool
tag = True

# DataType Output: str
message = "Hello World"

# DataType : bytes
x = b"Programming for Artists"

# DataType : int
x = 50
 
# DataType : float
y = 22.5
 
# DataType : complex
z = 7.5j
 
# DataType: list
shapes = ["sphere", "grid", "torus", "suzzane"]
 
# DataType : tuple
menu = ("file", "edit", "tools", "view")
 
# DataType : range
data = range(10)
 
# DataType : set
unique = {3, 5, 7}

# DataType Output: dict
my_dict = {"name": "Aviik", "speed": 60}
 

 

 
# DataType : bytearray
x = bytearray(4)
 
# DataType : memoryview
x = memoryview(bytes(6))

# %% [markdown]
# ## Operators

# %% [markdown]
# #### Arithmatic Operations
# ```
# +               # plus
# -               # minus
# *               # multiply
# /               # divide
# %               # remainder
# ```

# %% [markdown]
# #### Comparison Operations
# ```
# ==              # equal
# !=              # not equal
# <               # less than
# >               # greater than
# <=              # less than or equal
# >=              # greater than or equal
# ```

# %% [markdown]
# In Python, = is the assignment operator and == tests equality.

# %%
#TODO: some arithmatic operations
x = 50
y = 40
r = 3.7
s = 7.3

add_total = x + y + r + s

sub_total = x - y

div_result = x/y

mult_result = x*r

#TODO: some comparison operations

True == False
# Out:
# False

# %% [markdown]
# The types of locals and globals can be annotated as follows:

# %%
# Type anotations
# For most types, just use the name of the type in the annotation
# Note that mypy can usually infer the type of a variable from its value,
# so technically these annotations are redundant
x: int = 1
x: float = 1.0
x: bool = True
x: str = "test"
x: bytes = b"test"


my_var_a: int           # variable without initial value
myvar_a: float           # variable without initial value
myVar_c: str           # variable without initial value
some_number: int           # variable without initial value

# %%
# By default Python type is not strong. Type hints do not do any type checking.
x :int = 45.3

# %% [markdown]
# ### Advanced Annotations

# %%
from typing import get_type_hints
import __main__
get_type_hints(__main__)
# Out:
# {'x': int, 'my_var_a': int, 'myvar_a': float, 'myVar_c': str}
