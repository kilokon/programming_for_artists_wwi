# %% [markdown]
# Programming is the act of writing instructions that directly or indirectly control the hardware of a computer system. It involves low-level interactions with memory, processors, and electronic components, often using languages like C or Assembly. The goal is to ensure efficient execution, real-time performance, and reliable communication with hardware.
#
# Had it all been about hardware, then who codes the websites or databases or even our mobile apps. Hence, programming is the process of designing, writing, and analyzing algorithms to solve problems using computational methods.
#
# Although they are closely related, Computer Engineering and Computer Science focus on different aspects of computing and hence see programming differently:

# %% [markdown]
# ## Computer science (CS) and computer engineering (CE)
#
# Computer science is the study of algorithms: their properties, their development, and their efficient implementation Computer Science is an academic discipline grounded in theory and mathematics.
# Key Elements:
# - Algorithms and data structures
# - Programming languages
# - Theory of computation
# - Software development
# - Artificial intelligence
# - Operating systems and databases
#
# Computer Engineering is the discipline that combines electrical engineering and computer science to design, develop, and optimize computer hardware systems and embedded software.
# Key Elements:
# - Digital logic and circuit design
# - Microprocessors and microcontrollers
# - Embedded systems and firmware
# - Hardware-software integration
# - Computer architecture
# - Signal processing and electronics

# %% [markdown]
# Programming in VFX is the use of scripting and automation to enhance, streamline, and extend digital content creation workflows which aligns more with computer science. So we will explore the components of computer science.
#
# 1. __Algorithms and Data Structures__
# This is the heart of CS. An algorithm is a step-by-step procedure for solving a problem (like a recipe). A data structure is a way to organize and store data efficiently (like a filing cabinet). This area asks: What's the fastest way to sort a list? What's the best way to store connections in a social network?
#
# 2. __Programming Languages__
# This involves the design and implementation of languages used to talk to computers (like Python, Java, or C++). It also involves building compilers—programs that translate human-readable code into machine instructions.
#
# 3. __Software Development__
# The application of engineering principles to software creation. It's about the process of designing, developing, testing, and maintaining large-scale software systems in a team environment.
#
# 4. __Theory of Computation__
# The most mathematical and abstract area. It explores the fundamental capabilities and limits of computers. It asks questions like: "What can and cannot be computed?" (This is where you find concepts like Turing Machines).
#
# 5. __Artificial Intelligence (AI) and Machine Learning (ML)__
# The study of creating systems that can perform tasks that typically require human intelligence. This includes machine learning (systems that learn from data), computer vision, natural language processing (like ChatGPT), and robotics.
#
# 6. __Databases__
# The science of storing, managing, and retrieving vast amounts of information efficiently and securely. Every major website and app you use relies on a complex database system.
#
# 7. __Networking and Security__
# This focuses on how computers communicate with each other (the internet is the biggest example) and how to protect those communications and the systems themselves from attacks and unauthorized access.

# %% [markdown]
# ## Operating System
#
# An operating system (OS) is a software layer that manages computer hardware, provides a user interface, and enables applications to run. It acts as an intermediary between users, software, and hardware, ensuring efficient resource allocation and system operation. Examples include Windows, macOS, Linux, and Android.
#
# Core Functions of an *Operating System*:
# - __Process Management:__ Handles the creation, scheduling, and termination of processes (running programs).
# - __Memory Management:__ Allocates and manages system memory for processes and applications.
# - __File System Management:__ Organizes, stores, and retrieves data on storage devices.
# - __Device Management:__ Controls hardware devices (e.g., printers, disks) via drivers.
# - __User Interface:__ Provides a way for users to interact with the system (e.g., graphical or command-line interfaces).
# - __Security and Access Control:__ Ensures authorized access and protects system resources.
#
#
#
# Key components of an *Operating System*:
# 1. __Kernel:__
#    This is the core, heart, and brain of the operating system. It is the first part to load into memory when the computer starts up and remains there for the entire session. It has complete control over everything in the system and is responsible for the most critical tasks:
#    - __Process Management:__ Creates, schedules, and terminates processes (running programs). It decides which process gets to use the CPU, when, and for how long.
#
#    - __Memory Management:__ Keeps track of every byte of memory. It allocates memory to processes when they need it and deallocates it when they are finished. It also protects processes from accessing each other's memory.
#
#    - __Device Management:__ Acts as a bridge between hardware devices (printers, keyboards, disks) and applications through device drivers. The kernel talks to the driver, and the driver talks to the device.
#
#    - __System Calls Management:__ Provides a well-defined and secure interface (API) that applications can use to request services from the kernel, like reading a file or displaying something on the screen.
# 2. __User Interface:__
#     This is the part that users interact with directly. There are two primary types:
#
#    - __Command-Line Interface (CLI):__ A text-based interface where users type commands to perform tasks (e.g., Windows Command Prompt, Linux Terminal). It's powerful and lightweight but has a steeper learning curve.
#
#    - __Graphical User Interface (GUI):__ A visual interface with windows, icons, menus, and pointers (e.g., Windows Desktop, macOS Finder, GNOME on Linux). It is much more user-friendly and is the standard for most personal computers.
# 3. __File System Management:__ This component manages all file-related activities. It is responsible for:
#    - Organizing: How data is stored and retrieved from storage devices (HDDs, SSDs).
#    - Naming: Governing how files are named, organized into folders/directories, and accessed.
#    - Permissions: Controlling who (which users) can read, write, or execute a file.
#
# 4. __Device Drivers:___ These are specialized programs that act as translators between the operating system (specifically the kernel) and a specific piece of hardware.
#
# 5. __System Libraries:__ Provide reusable global variables, functions and APIs for applications to interact with the OS.
# 6. __Security Module:__ Ensures system integrity and data protection.
# 7. __Networking__ (optional, in network-enabled OS): Manages network communication, including protocols like TCP/IP.

# %% [markdown]
# ## Programming Language
# A programming language is a formal system of notation used to write instructions that a computer can execute to perform tasks or solve problems. It provides a structured way for programmers to communicate with computers, defining both the syntax (rules for writing valid code) and semantics (the meaning or behavior of that code).
#
#
# __Syntax and Formal Specification:__ The grammar or structure of the language, detailing how code must be written. This includes keywords, operators, data types, and rules for forming valid statements (e.g., how to write a function or loop). For example, a book might describe Python’s syntax, noting that indentation defines code blocks.The formal grammar of the language is often written in a notation like Backus-Naur Form (BNF) or its variants. It defines the correct structure of programs what constitutes a valid statement, expression, function declaration, etc.
#
# __Semantics:__ What the code does when executed. Semantics define the meaning of each construct, such as how a for loop iterates or how variables store data. For instance, a book might clarify that in C, int x = 5; declares an integer variable initialized to 5.
#
# __Purpose and Paradigm:__ The language’s intended use (e.g., web development, data science, or systems programming) and its programming paradigm (e.g., object-oriented, functional, or procedural). For example, Java is known for its use in enterprise applications and its object-oriented nature.
#
# __Standard Library and Features:__ Documentation on built-in functions, libraries, or tools that come with the language. For example, a Python book might detail the math module or list comprehension features.

# %% [markdown]
# ## Shell
# The shell interprets user commands and communicates them to the OS kernel for execution. either via commands (CLI) or graphical elements (GUI).Shells often support scripting, allowing users to automate tasks by writing scripts (e.g., Bash scripts or PowerShell scripts).
#
# __Interface Type:__ Shells can be:
#    - __Command-Line Interface (CLI):__ Text-based, where users type commands (e.g., Bash, PowerShell).
#
#    - __Graphical User Interface (GUI):__ Less common, but some shells provide graphical environments (e.g., Windows Explorer).

# %% [raw]
# Backus-Naur Form (BNF): This is a notation for defining the grammatical structure of a language. A simple assignment statement in BNF.
# <statement> ::= <variable> "=" <expression>
# ├── <variable> ::= "a" | "b" | "c" |...| "z"
# └── <expression> ::= <term> | <term> "+" <expression>
#     └── <term> ::= <number> | <variable>
#         └── <number> ::= "0" | "1" | ... | "9"

# %% [markdown]
# ## Terminal
# A Terminal is a program that provides a text-based interface to interact with a shell. It handles input/output. A CLI shell is the software that runs inside the terminal and interprets commands.
# Examples:
# - Windows Terminal
# - GNOME Terminal (Linux)
# - iTerm2 (macOS)

# %% [markdown]
# ## Scripting Interface
# A scripting interface is a set of tools and APIs that allow an application to be controlled or extended using a scripting language. It allows to automate tasks, create new features, or customize an application's behavior without needing to change its core source code. A scripting interface works by exposing a part of the application's internal "object model" to an external scripting language.
#
# The main components of a scripting interface include:
#
# __The Scripting Engine:__ This is a component within the application that can interpret and execute code written in a specific scripting language (like Python, Lua, or JavaScript). It's the interpreter for the script.
#
# __The API (Application Programming Interface):__ This is a set of classes, objects, and functions that the application makes available to the scripting engine.
#
# __The Script:__ This is the actual code written by the user. It calls the functions and manipulates the objects exposed by the API to perform tasks.

# %% [markdown]
#                             +--------------------------+
#                             |      Scripting Layer     |
#                             |(e.g., Python in Blender) |
#                             +--------------------------+
#                             |  User Applications       |
#                             |  (e.g., Word, Browser)   |
#                             +--------------------------+
#                             |  Programming Language    |
#                             |  (Syntax, Semantics)     |
#                             +--------------------------+
#                             |  Terminal                |
#                             |  (e.g., Bash, PowerShell)|
#                             +--------   CLI  ----------+
#                             |  Shell                   |
#                             |  (Command Interpreter)   |
#                             +--------------------------+
#                             |  OS Kernel               |
#                             |  (Linux, NT Kernel)      |
#                             +--------------------------+
#                             |  Hardware                |
#                             |  (CPU, RAM, Devices)     |
#                             +--------------------------+

# %% [markdown]
# ## Python: Programming Language

# %% [markdown]
# ### Setting up a development environment
#
# #### Installing a Shell
# Install https://github.com/PowerShell/PowerShell
# #### Installing Python
# https://www.python.org/downloads/
# #### Installing Terminal
# 1. https://ghostty.org/
# 2. https://github.com/alacritty/alacritty
# 3. https://github.com/microsoft/terminal
# #### Installing a REPL
# https://github.com/bpython/bpython
# #### Installing Jupyter
# #### Installing VCS
# https://git-scm.com/downloads
# #### Installing an IDE
# https://cursor.com/
# https://code.visualstudio.com/
# https://neovim.io/

# %% [markdown]
# ## Version Control System
